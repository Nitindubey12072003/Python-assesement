# %% [markdown]
# # Question 1: What is a random variable in probability theory ?

# %% [markdown]
# # Answer.
# A random variable in probability theory is a variable that assigns a numerical value to the outcome of a random experiment.
#
# A random variable is a function that maps outcomes from a sample space (set of all possible outcomes) to real numbers.
#
# It allows us to quantify uncertain events in terms of numbers so that probability and statistics can be applied.
#
# **Types of Random Variables:**
#
# **1.** Discrete Random Variable
#
# Takes on a countable number of values (finite or countably infinite).
#
# Example: Number of heads when tossing 3 coins → values {0,1,2,3}.
#
# **2.** Continuous Random Variable
#
# Takes on values from an interval or continuum of real numbers (uncountable).
#
# Example: The time a student takes to finish an exam → any real value in hours or minutes.

# %% [markdown]
# # Question 2: What are the types of random variables ?

# %% [markdown]
# # Answer.
# **1.Discrete Random Variable**
#
# **.** Takes on a finite or countably infinite set of distinct values.
#
# **.** Usually represents things you count.
#
# **.** Probability is described using a probability mass function (PMF).
#
# **Example:**
#
# Number of goals in a football match → {0,1,2,…}
#
# Number of heads in 3 coin tosses → {0,1,2,3}
#
# **2.Continuous Random Variable**
#
# **.** Takes values from an uncountable set, usually an interval of real numbers.
#
# **.** Usually represents things you measure.
#
# **.** Probability is described using a probability density function (PDF).
#
# **Example:**
#
# **.** Height of students in a class → any real value in (say) 140 cm to 200 cm
#
# **.** Time taken to run a marathon → any non-negative real number

# %% [markdown]
# # Question 3: Explain the difference between discrete and continuous distributions.

# %% [markdown]
# # Answer.
# **1. Discrete Distribution**
#
# A discrete distribution describes probabilities for a discrete random variable (one that takes countable values).
#
# Values: Finite or countably infinite.
#
# Probability Rule: Each value has a specific probability given by a Probability Mass Function (PMF).
#
# Total Probability:
#
# ∑ 𝑃(𝑋=𝑥𝑖) =1 ∑ P(X=xi) = 1
#
# **Examples of Discrete Distributions:**
#
# Binomial distribution (number of successes in n coin tosses)
#
# Poisson distribution (number of arrivals at a bus stop in an hour)
#
# Geometric distribution (number of trials until first success)
#
# **2. Continuous Distribution**
#
# A continuous distribution describes probabilities for a continuous random variable (one that can take infinitely many values in an interval).
#
# Values: Uncountably infinite (real numbers in a range).
#
# Probability Rule: Probability at a single point is zero. Instead, probability is given over an interval using a Probability Density Function (PDF).
#
# Total Probability:
#
# ∫−∞ ∞  𝑓 (𝑥) 𝑑𝑥=1 ∫ −∞ ∞ f(x) dx= 1
#
# **Examples of Continuous Distributions:**
#
# Normal distribution (heights, IQ scores, etc.)
#
# Exponential distribution (time between arrivals)
#
# Uniform distribution (all values equally likely in an interval)

# %% [markdown]
# # Question 4: What is a binomial distribution, and how is it used in probability ?

# %% [markdown]
# # Answer.
# Binomial Distribution
#
# A binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes:
#
# Success (with probability p)
#
# Failure (with probability 𝑞 =1 −𝑝 q= 1 − p)
#
# **Conditions for a Binomial Distribution :**
#
# **.** A fixed number of trials (n)
#
# **.** Each trial has exactly two outcomes (success/failure)
#
# **.** Probability of success (p) is the same for every trial
#
# **.** All trials are independent

# %% [markdown]
# # Question 5: What is the standard normal distribution, and why is it important ?

# %% [markdown]
# # Answer.
# Standard Normal Distribution
#
# The standard normal distribution is a special case of the normal distribution with:
#
# Mean (𝜇μ) = 0
#
# Standard deviation (σ) = 1
#
# Its probability density function (PDF) is:
#
# 𝑓(𝑧) = 1 2 𝜋 𝑒 − 𝑧 2 2 ,−∞<𝑧<∞f(z)= 2π
# 	​
# Here, the random variable is usually denoted by 𝑍
#
# **Why It Is Important :**
#
# Basis of the Normal Distribution Family
#
# Any normal distribution can be converted (standardized) into the standard normal using:
#
# Z =  X−μ / σ
#
# This process is called standardization (or z-transformation).
#
# Probability Calculations via Z-tables
#
# The standard normal allows us to compute probabilities and percentiles using Z-tables (or software).
#
# Example: Find probability that a value is within 2 standard deviations of the mean.
#
# Central Limit Theorem (CLT)
#
# Many real-world distributions, when aggregated, approximate the standard normal for large samples.
#
# Benchmark in Statistics
#
# Widely used in hypothesis testing, confidence intervals, and statistical quality control.
#
# Example
#
# Suppose heights of men follow
# 𝑁(170,102)
# N(170,102).
#
# What is the probability a man is taller than 180 cm?
#
# We standardize:
#
# 𝑍
# =
# 180
# −
# 170
# 10
# =
# 1
# Z=
# 10
# 180−170
# 	​
#
# =1
#
# Now we just look up
# 𝑃
# (
# 𝑍
# >
# 1
# )
# P(Z>1) from the standard normal table ≈ 0.1587 (15.87%).

# %% [markdown]
# # Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics ?

# %% [markdown]
# # Answer.
# The Central Limit Theorem (CLT) states that:
#
# When you repeatedly take large enough random samples from any population (regardless of the population’s distribution), the distribution of the sample means will approach a normal distribution (bell curve) as the sample size increases.
#
# In other words:
#
# The means of these samples will be normally distributed.
#
# The mean of the sampling distribution will be equal to the population mean.
#
# The standard deviation of the sampling distribution (called the standard error) will equal the population standard deviation divided by the square root of the sample size:
#          σ xˉ​=n / ​σ
#
# Key conditions:
#
# The sample size should be "large enough" (commonly
# 𝑛
# ≥
# 30
# n≥30).
#
# The samples should be independent and randomly selected.
#
# The underlying population can be of any distribution (not necessarily normal).​

# %% [markdown]
# # Question 7: What is the significance of confidence intervals in statistical analysis ?

# %% [markdown]
# # Answer.
# A confidence interval is a range of values, derived from sample data, that is likely to contain the true population parameter (such as the mean or proportion) with a certain level of confidence.
#
# For example, a 95% confidence interval means that if we repeatedly take samples and calculate the interval, about 95% of those intervals would contain the true population parameter.
#
#  **its significant in statistical analysis :**
#
# **Provides an estimate with uncertainty:**
#
# A point estimate (like a sample mean) gives one value, but it doesn’t show how accurate that estimate is. A confidence interval shows the range within which the true value likely lies, giving a sense of reliability.
#
# **Quantifies precision:**
#
# Narrow intervals indicate high precision and more reliable estimates, while wider intervals indicate greater uncertainty.
#
# **Informs decision-making:**
#
# By knowing the interval within which the true value may lie, analysts and researchers can make better-informed conclusions and avoid overconfidence.
#
# **Helps in hypothesis testing:**
#
# If a hypothesized value (e.g., population mean) falls outside the confidence interval, it may indicate that the hypothesis is unlikely to be true.

# %% [markdown]
# # Question 8: What is the concept of expected value in a probability distribution ?

# %% [markdown]
# # Answer.
# The expected value (EV), often denoted as
# 𝐸
# (
# 𝑋
# )
# E(X), is a measure of the average outcome you would expect if you repeated a random experiment many times.
#
# It represents the long-term mean or the weighted average of all possible outcomes, where each outcome is weighted by its probability of occurring.
#
# Formula:
#
# For a discrete random variable
# 𝑋
# X with possible outcomes
# 𝑥
# 𝑖
# x
# i
# 	​
#
#  and probabilities
# 𝑃
# (
# 𝑥
# 𝑖
# )
# P(x
# i
# 	​
#
# ), the expected value is:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# (
# 𝑥
# 𝑖
# ×
# 𝑃
# (
# 𝑥
# 𝑖
# )
# )
# E(X)=∑(x
# i
# 	​
#
# ×P(x
# i
# 	​
#
# ))
#
# For a continuous random variable, the formula involves integration, but the concept is the same — it's the mean outcome weighted by probability.

# %%
# Question 9: Write a Python program to generate 1000 random numbers from a normal
#distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
#deviation using NumPy, and draw a histogram to visualize the distribution.
import numpy as np
import matplotlib.pyplot as plt
# Parameters
mean = 50
std_dev = 5
num_samples = 1000
# Generate random numbers from local distribution
data = np.random.normal(loc=mean,scale=std_dev,size=num_samples)
# Compute mean and standard deviation
calculated_mean = np.mean(data)
calculated_std_dev = np.std(data)
print(f"Calculated Mean: {calculated_mean}")
print(f"Calculated Standard Deviation: {calculated_std_dev}")

# Plot histogram
plt.hist(data,bins=30,edgecolor='black')
plt.title("Histogram of normally distributed data")
plt.xlabel("value")
plt.ylabel("Frequency")
plt.axvline(calculated_mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean = {calculated_mean:.2f}")
plt.legend()
plt.show()
# Out:
# Calculated Mean: 49.955172117442736
# Calculated Standard Deviation: 4.746803158786934

# %%
#You are working as a data analyst for a retail company. The company has
#collected daily sales data for 2 years and wants you to identify the overall sales trend.
#daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
# Explain how you would apply the Central Limit Theorem to estimate the average sales
#with a 95% confidence interval.Write the Python code to compute the mean sales and its confidence interval.
import numpy as np
from scipy import stats
# Daily sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
# convert to numpy area
sales = np.array(daily_sales)
# sample size
n = len(sales)
# Sample mean and standard deviation
mean_sales = np.mean(sales)
std_sales = np.std(sales,ddof=1)  # ddof=1 for sample standard deviation
# confidence level
confidence = 0.95
alpha = 1-confidence
# t-score for the 95% confidence interval
t_score = stats.t.ppf(1 - alpha/2, df=n-1)
# Margin of error
margin_error = t_score * (std_sales / np.sqrt(n))

# Confidence interval
lower_bound = mean_sales - margin_error
upper_bound = mean_sales + margin_error

# Output
print(f"Mean Daily Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Mean Daily Sales: 248.25
# 95% Confidence Interval: (240.17, 256.33)

# %% [markdown]
# Q1. What are data structures, and why are they important?
# Answer. Data structures in Python are ways to store and organize data so it can be used efficiently. Python provides several built-in data structures that make it easy to work with different types of data.
# Data Structures Important in Python :
# 1.Efficient Data Management.
# 2. Built in Convenience.
# 3.Enables Problem Solving.
# Q2.Explain the difference between mutable and immutable data types with examples.
# Answer. In Python, mutability refers to whether or not an object’s value can be changed after it is created.
# -Mutable Data Types:
# -Can be changed after creation.
# -Modifying the object does not create a new one.
# Examples: list, dict, set.
# Example:
# my_list = [1, 2, 3]
# my_list[0] = 10
# print(my_list)  # Output: [10, 2, 3]
# Immutable Data Types
# Cannot be changed after creation.
# Any change creates a new object in memory.
# Examples: str, tuple
# Example:
# name = "Alice"
# name = name.replace("A", "M")
# print(name)  # Output: "Mlice"
# The original string "Alice" wasn't changed — a new string "Mlice" was created.
# Q3.What are the main differences between lists and tuples in Python?
# Answer.Both lists and tuples are used to store collections of items in Python, but they have important differences in behavior and usage.
# Feature                            List                      Tuple
# Mutablity                        Mutable                    Immutable
# Syntax	                    Square brackets []	            Parentheses ()
# Memory               use more memory                   memory efficinet
# Q4.Describe how dictionaries store data.
# Answer.A dictionary in python is a collection of key-value pairs, where:
# Each key must be unique and immutable.
# Each value can be of any data type and can be repeated.
# Example:
# student = {
#     "name": "Alice",
#     "age": 21,
#     "course": "Math"
# }
# print(student["age"])  # Output: 21
# Q5.Why might you use a set instead of a list in Python?
# Answer.We might choose a set over a list when:
# You need unique elements.
# You want faster membership testing.
# You are doing set operations.
# Q6.What is a string in Python, and how is it different from a list?
# Answer.A string in Python is a sequence of characters enclosed in quotes.
# Example= "Nitin".
# It can contain letters, numbers, symbols, or spaces.
# Strings are immutable, meaning you can't change them after creation.
# Feature	                       String	                                  List
# Data Type	              Sequence of characters	       Sequence of any data type
# Syntax	                 Enclosed in " "        	Enclosed in square brackets []
# Mutability	               Immutable	                          Mutable
# Q7. How do tuples ensure data integrity in Python?
# Answer.Tuples in Python are immutable, meaning their values cannot be changed after they are created. This property plays a key role in ensuring data integrity.Tuples can be shared between functions or threads without worrying about them being altered.
# Q8.What is a hash table, and how does it relate to dictionaries in Python?
# Answer.A hash table is a data structure that maps keys to values using a process called hashing. It allows for very fast data access — typically in O(1) (constant time). A dict in Python is implemented using a hash table.
# So when you write:
# person = {"name": "Alice", "age": 30}
# Here's what happens behind the scenes:
# "name" is hashed using hash("name").
# Python finds a memory location (bucket) to store "name": "Alice".
# Same for "age": 30.
# Q9.Can lists contain different data types in Python?
# Answer.Python lists are flexible and can store elements of mixed data types within the same list. Example:
# mixed_list = [1, "hello", 3.14, True, None, [5, 6], {"key": "value"}]
# print(mixed_list)
# Q10.Explain why strings are immutable in Python.
# Answer.In Python, strings are immutable, meaning once a string is created, it cannot be changed. Any operation that modifies a string actually creates a new string object.
# Efficiency and Performance
# Security and Reliability
# Hashing and Dictionary Keys
# Thread Safety
# Q11.What advantages do dictionaries offer over lists for certain tasks?
# Answer.Dictionaries (dict) and lists (list) are both built-in data structures in Python, but dictionaries offer major advantages in certain situations — especially when working with key-based data.
# Fast Lookups (O(1)).
# Key-Value Mapping.
# Improved Readability and Maintainability.
# Avoiding Duplicates in Keys.
# Dynamic and Flexible Access.
# Q12.Describe a scenario where using a tuple would be preferable over a list?
# Answer.A tuple is preferable over a list when you want to store a fixed collection of values that should not change throughout the program — in other words, when immutability is desired.
# Immutability
# Faster performance
# Hashable
# Q13.How do sets handle duplicate values in Python?
# Answer.In Python, sets automatically eliminate duplicate values. When you add duplicate elements to a set, only one instance of each unique value is kept.
# Sets are unordered collections of unique elements.
# Behind the scenes, sets use a hash table to keep track of elements.
# If a duplicate value is added, Python checks the hash and discards it if it's already present.
# Q14.How does the “in” keyword work differently for lists and dictionaries?
# Answer.The in keyword in Python is used to check membership, but its behavior differs between lists and dictionaries.
# In a List checks if a value exists among the elements of the list.
# In a dictionary checks only the keys, not the values.
# Q15.Can you modify the elements of a tuple? Explain why or why not?
# Answer.No, you cannot modify the elements of a tuple in Python — tuples are immutable.Once a tuple is created, its size and elements cannot be changed.
# You can’t add, remove, or modify items in it.
# my_tuple = (10, 20, 30)
# my_tuple[1] = 99    #This will raise an error
# Why Are Tuples Immutable:
# Data Integrity
# Hashable
# Performance
# Q16.What is a nested dictionary, and give an example of its use case?
# Answer.A nested dictionary is a dictionary inside another dictionary. It allows you to organize data in a hierarchical or structured way, like a tree.
# students = {
#     "101": {"name": "Alice", "age": 20, "grade": "A"},
#     "102": {"name": "Bob", "age": 22, "grade": "B"},
#     "103": {"name": "Charlie", "age": 21, "grade": "A"}
# }
# Here, the outer dictionary uses student IDs as keys, and each value is another dictionary with the student's details.
# #Accessing nesting values:
# print(students["102"]["name"])  # Output: Bob
# print(students["103"]["grade"]) # Output: A
# Q17.Describe the time complexity of accessing elements in a dictionary?
# Answer.Time Complexity of Accessing Elements in a Dictionary (Python)
# Accessing an element in a Python dictionary using a key:
# value = my_dict["some_key"]
#  Average Case: O(1) (Constant Time)
# Python dictionaries use hash tables internally.
#
# When you access a key, Python computes the key's hash and directly looks up the corresponding index — this is very fast.
#  Worst Case: O(n) (Rare)
# This occurs only in rare cases of hash collisions (when many keys hash to the same index).
# Python handles collisions using open addressing and resizing strategies, so this worst case is extremely uncommon.
# Q18.In what situations are lists preferred over dictionaries?
# Answer. Situations where list are preferred over dictionaries:
# When order matters.
# When you don't need key-value pairs.
# Index based access or positioning is important.
# You need to perform slicing or sorting.
# Smaller memory overhead.
# Q19.Why are dictionaries considered unordered, and how does that affect data retrieval?
# Answer.They did not guarantee the order in which keys were inserted.
# The internal hash table used for storing key-value pairs did not maintain insertion sequence.
# How does that affect data retrieval:
# Key-Based Access Only.
# You Can’t Do This:
# print(my_dict[0])  #Raises KeyError (not index-based).
# Q20.Explain the difference between a list and a dictionary in terms of data retrieval.
# Answer.Difference Between a List and a Dictionary in Terms of Data Retrieval:
# Feature	                      List	                             Dictionary
# Access Method	        By index (position)	        By key (name or identifier)
# Example Access	            my_list[0]	                  my_dict["name"]
#  Use	          Ordered collection of values	Unordered collection of key-value
# Speed	                O(1)for index access	    O(1)average case for key access
# Suitable for	   Sequential or positional data	     Structured or labeled data

# %%
###1.Write a code to create a string with your name and print it ###
# Create a string with your name
name = "Nitin Dubey"

# Print the string
print("My name is:", name)
# Out:
# My name is: Nitin Dubey

# %%
###2.Write a code to find the length of the string "Hello World"
# Define the string
text = "Hello World"

# Find and print the length
length = len(text)
print("Length of the string is:", length)
# Out:
# Length of the string is: 11

# %%
###3. Write a code to slice the first 3 characters from the string "Python Programming"
# Define the string
text = "Python Programming"

# Slice the first 3 characters
sliced = text[:3]

# Print the result
print("First 3 characters:", sliced)
# Out:
# First 3 characters: Pyt

# %%
###4.Write a code to convert the string "hello" to uppercase?
# Define the string
text = "hello"

# Convert to uppercase
upper_text = text.upper()

# Print the result
print("Uppercase:", upper_text)
# Out:
# Uppercase: HELLO

# %%
###5.Write a code to replace the word "apple" with "orange" in the string "I like apple"?
# Define the string
text = "I like apple"
# Replace 'apple' with 'orange'
new_text = text.replace("apple", "orange")
print(new_text)
# Out:
# I like orange

# %%
###6.Write a code to create a list with numbers 1 to 5 and print it
# Create a list with numbers 1 to 5
numbers = [1, 2, 3, 4, 5]
print("List of numbers:", numbers)
# Out:
# List of numbers: [1, 2, 3, 4, 5]

# %%
###7.P Write a code to append the number 10 to the list [1, 2, 3, 4]
# Define the list
numbers = [1, 2, 3, 4]

# Append the number 10
numbers.append(10)

# Print the updated list
print("Updated list:", numbers)
# Out:
# Updated list: [1, 2, 3, 4, 10]

# %%
###8.Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
# Define the list
numbers = [1, 2, 3, 4, 5]

# Remove the number 3
numbers.remove(3)

# Print the updated list
print("Updated list:", numbers)
# Out:
# Updated list: [1, 2, 4, 5]

# %%
###9.Write a code to access the second element in the list ['a', 'b', 'c', 'd']
# Define the list
letters = ['a', 'b', 'c', 'd']

# Access the second element (index 1)
second_element = letters[1]

# Print the result
print("Second element:", second_element)
# Out:
# Second element: b

# %%
###10.Write a code to reverse the list [10, 20, 30, 40, 50].
# Define the list
numbers = [10, 20, 30, 40, 50]

#Reverse the list in-place
numbers.reverse()

# Print the reversed list
print("Reversed list:", numbers)
# Out:
# Reversed list: [50, 40, 30, 20, 10]

# %%
###11.Write a code to create a tuple with the elements 100, 200, 300 and print it.
# Create a tuple
my_tuple = (100, 200, 300)

# Print the tuple
print("Tuple:", my_tuple)
# Out:
# Tuple: (100, 200, 300)

# %%
###12.Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
colors = ('red', 'green', 'blue', 'yellow')
# Access the second-to-last element using negative indexing
second_to_last = colors[-2]
print("Second-to-last element:", second_to_last)
# Out:
# Second-to-last element: blue

# %%
###13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).
# Define the tuple
numbers = (10, 20, 5, 15)
minimum = min(numbers)
print("Minimum number:", minimum)
# Out:
# Minimum number: 5

# %%
###14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
# Define the tuple
animals = ('dog', 'cat', 'rabbit')
index = animals.index("cat")
print("Index of 'cat':", index)
# Out:
# Index of 'cat': 1

# %%
###15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits = ("apple", "banana", "orange")

# Check if 'kiwi' is in the tuple
if "kiwi" in fruits:
    print("Kiwi is in the tuple.")
else:
    print("Kiwi is not in the tuple.")

# %%
###16.. Write a code to create a set with the elements 'a', 'b', 'c' and print it.
# Creating a set with elements 'a', 'b', and 'c'
my_set = {'a', 'b', 'c'}
print(my_set)
# Out:
# {'c', 'a', 'b'}

# %%
###17.Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
# Creating the set
my_set = {1, 2, 3, 4, 5}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
###18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.
# Creating the set
my_set = {1, 2, 3, 4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
###19.Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
# Creating the sets
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
###20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
# Creating the sets
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {2, 3}

# %%
###21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it
# Create the dictionary
person = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
###22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
# Original dictionary
person = {'name': 'John', 'age': 25}

# Add new key-value pair
person['country'] = 'USA'


print(person)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
###23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
# Dictionary
person = {'name': 'Alice', 'age': 30}
# Access value using the key "name"
name_value = person['name']
print(name_value)
# Out:
# Alice

# %%
###24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
# Original dictionary
person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
# Remove the key "age"
del person['age']
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
###25.. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
# Dictionary
person = {'name': 'Alice', 'city': 'Paris'}

# Check if "city" key exists
if 'city' in person:
    print("Key 'city' exists in the dictionary.")
else:
    print("Key 'city' does not exist in the dictionary.")
# Out:
# Key 'city' exists in the dictionary.

# %%
###26. Write a code to create a list, a tuple, and a dictionary, and print them all.
# Create a list
my_list = [1, 2, 3, 4, 5]

# Create a tuple
my_tuple = ('apple', 'banana', 'cherry')

# Create a dictionary
my_dict = {'name': 'Alice', 'age': 25, 'city': 'London'}

# Print all
print("List:", my_list)
print("Tuple:", my_tuple)
print("Dictionary:", my_dict)
# Out:
# List: [1, 2, 3, 4, 5]
# Tuple: ('apple', 'banana', 'cherry')
# Dictionary: {'name': 'Alice', 'age': 25, 'city': 'London'}

# %%
 ###27.Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result(replaced).


# Create a list of 5 random numbers between 1 and 100
random_numbers = [5,16,34,56,67]
random_numbers.sort()
print("Sorted list:", random_numbers)
# Out:
# Sorted list: [5, 16, 34, 56, 67]

# %%
###28. Write a code to create a list with strings and print the element at the third index.
# Create a list with strings
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# Print the element at the third index (index 3)
print("Element at index 3:", fruits[3])
# Out:
# Element at index 3: date

# %%
###29.Write a code to combine two dictionaries into one and print the result.
# Two dictionaries
dict1 = {'name': 'Alice', 'age': 25}
dict2 = {'city': 'Paris', 'country': 'France'}
# Combine dictionaries
combined_dict = {**dict1, **dict2}
print("Combined Dictionary:", combined_dict)
# Out:
# Combined Dictionary: {'name': 'Alice', 'age': 25, 'city': 'Paris', 'country': 'France'}

# %%
###30. Write a code to convert a list of strings into a set.
string_list = ['apple', 'banana', 'cherry', 'apple']
# Convert list to set
string_set = set(string_list)

print("Set:", string_set)
# Out:
# Set: {'banana', 'cherry', 'apple'}

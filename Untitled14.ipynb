# %%
# : Read the Bike Details dataset into a Pandas DataFrame and display itsfirst 10 rows.

import pandas as pd

# Read the dataset (make sure the file is in your working directory)
df = pd.read_csv("BIKE DETAILS.csv")

# Display the first 10 rows
print(df.head(10))

# %%
# Check for missing values in all columns and describe your
#approach forhandling them.(Include your Python code and output in the code box below.)
import pandas as pd

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Check for missing values in all columns
print("Missing values in each column:\n")
print(df.isnull().sum())

# Display total missing values
print("\nTotal missing values in dataset:", df.isnull().sum().sum())

# ----- Handling Missing Values -----
# Approach:
# 1. If numerical columns have few missing values → fill with mean/median.
# 2. If categorical columns have missing values → fill

# %%
#Plot the distribution of selling prices using a histogram and describe the
#overall trend .
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Plot histogram for Selling Price
plt.figure(figsize=(10,6))
sns.histplot(df['selling_price'], kde=True, color='skyblue', bins=30)

plt.title('Distribution of Selling Prices', fontsize=14)
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Create a bar plot to visualize the average selling price for each seller_type
#and write one observation.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Group by seller_type and calculate average selling price
avg_price = df.groupby('seller_type')['selling_price'].mean().reset_index()

# Plot bar chart
plt.figure(figsize=(8,5))
sns.barplot(x='seller_type', y='selling_price', data=avg_price, palette='viridis')

plt.title('Average Selling Price by Seller Type', fontsize=14)
plt.xlabel('Seller Type')
plt.ylabel('Average Selling Price')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Compute the average km_driven for each ownership type (1st owner,
#2nd owner, etc.), and present the result as a bar plot.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Group by ownership and calculate average km_driven
avg_km = df.groupby('owner')['km_driven'].mean().reset_index()

# Plot bar chart
plt.figure(figsize=(8,5))
sns.barplot(x='owner', y='km_driven', data=avg_km, palette='coolwarm')

plt.title('Average Kilometers Driven by Ownership Type', fontsize=14)
plt.xlabel('Ownership Type')
plt.ylabel('Average Kilometers Driven')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Use the IQR method to detect and remove outliers from the km_driven
#column. Show before-and-after summary statistics.
import pandas as pd

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# ---- Before removing outliers ----
print("Before Removing Outliers:\n")
print(df['km_driven'].describe())

# ---- IQR Method ----
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper limits
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# Filter out outliers
df_no_outliers = df[(df['km_driven'] >= lower_limit) & (df['km_driven'] <= upper_limit)]

# ---- After removing outliers ----
print("\nAfter Removing Outliers:\n")
print(df_no_outliers['km_driven'].describe())

# Display number of removed rows
removed = df.shape[0] - df_no_outliers.shape[0]
print(f"\nTotal outliers removed: {removed}")

# %%
#Create a scatter plot of year vs. selling_price to explore the
#relationship between a bike's age and its price.
#(Include your Python code and output in the code box below.)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Scatter plot: Year vs. Selling Price
plt.figure(figsize=(10,6))
sns.scatterplot(x='year', y='selling_price', data=df, color='teal', alpha=0.7)

plt.title('Relationship Between Year and Selling Price', fontsize=14)
plt.xlabel('Year of Manufacture')
plt.ylabel('Selling Price')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
#Convert the seller_type column into numeric format using one-hot
#encoding. Display the first 5 rows of the resulting DataFrame.
import pandas as pd

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# One-hot encode the seller_type column
df_encoded = pd.get_dummies(df, columns=['seller_type'], drop_first=False)

# Display the first 5 rows of the encoded DataFrame
print(df_encoded.head())

# %%
#Generate a heatmap of the correlation matrix for all numeric columns.
#What correlations stand out the most?
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the dataset
df = pd.read_csv("Bike Details.csv")

# Compute correlation matrix for numeric columns
corr = df.corr(numeric_only=True)

# Plot the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title("Correlation Heatmap of Numeric Columns", fontsize=14)
plt.show()

# %% [markdown]
# #Summarize your findings in a brief report:
# #● What are the most important factors affecting a bike's selling price?
# #● Mention any data cleaning or feature engineering you performed.
# Bike Selling Price Analysis Report
# 1. Most Important Factors Affecting Selling Price
#
# Based on the analysis and visualizations:
#
# Year of Manufacture: Newer bikes (higher year) have significantly higher selling prices — showing strong positive correlation.
#
# Kilometers Driven (km_driven): Higher mileage generally leads to lower prices, indicating a negative correlation.
#
# Seller Type (seller_type): Bikes sold by dealers or trustmark dealers tend to have higher average selling prices compared to individual sellers.
#
# Ownership (owner): First-owner bikes usually have higher selling prices compared to second or third-owner bikes.

# %% [markdown]
# # Question1. What is Object-Oriented Programming (OOP)

# %% [markdown]
# #Answer:
# Object-Oriented Programming (OOP) is a programming paradigm that organizes code using objects, which combine data (attributes) and behavior (methods). It allows you to model real-world things more naturally in code.
#
# **Core Concept of python :**
#
# **1.** Class
#
# **2.** Object
#
# **3.** Encapsulation
#
# **4.** Abstraction
#
# **5.** Inheritance
#
# **6.** Polymorphism

# %% [markdown]
# # Question2.  What is a class in OOP?

# %% [markdown]
# #Answer:
# A class in OOP is a blueprint or template used to create objects. It defines the attributes (data) and methods (behavior) that the objects created from the class will have.

# %% [markdown]
# # Question3.  What is an object in OOP?

# %% [markdown]
# #Answer:
# An object is created from a class and holds actual values for the properties defined by the class.
# Data → called attributes
#
# Behavior → called methods

# %% [markdown]
# #Question4. What is the difference between abstraction and encapsulation?

# %% [markdown]
# #Answer:
# **Abstraction.** Hiding implementation details and showing only essential features
#
# **Encapsulation.** Hiding internal data by restricting direct access to it.

# %% [markdown]
# #Question5.  What are dunder methods in Python?

# %% [markdown]
# #Answer:
# Dunder methods (short for Double UNDERscore) are special methods in Python that have names starting and ending with double underscores, like __init__, __str__, or __add__.

# %% [markdown]
# #Question6. Explain the concept of inheritance in OOP.

# %% [markdown]
# #Answer.
# Inheritance is one of the core principles of Object-Oriented Programming (OOP). It allows a class (called a child class or subclass) to inherit properties and behaviors (methods and attributes) from another class (called a parent class or superclass).

# %% [markdown]
# #Question7. What is polymorphism in OOP?

# %% [markdown]
# #Answer.
# Polymorphism means “many forms”. It allows objects of different classes to be treated as objects of a common superclass. It enables a single function, method, or operator to behave differently based on the object it is acting on.

# %% [markdown]
# #Question8. How is encapsulation achieved in Python?

# %% [markdown]
# #Answer.
# Encapsulation is the OOP principle of hiding internal data and restricting direct access to it. It helps protect object integrity by exposing only necessary parts and preventing unwanted interference or misuse.
#
# **Encapsulation in Python is achieved using:**
#
# Access Modifiers
#
# Getter and Setter methods
#
# Properties (@property decorator)

# %% [markdown]
# #Question9. What is a constructor in Python?

# %% [markdown]
# #Answer.
# A constructor in Python is a special method used to initialize an object when it is created. It sets up the initial state of the object by assigning values to its attributes.
#
# In Python, the constructor method is called __init__():
#
# Automatically called when a new object is created.
#
# Commonly used to assign values to object properties.

# %% [markdown]
# #Question10. What are class and static methods in Python?

# %% [markdown]
# #Answer.
# In Python, class methods and static methods are special types of methods that are defined using decorators: @classmethod and @staticmethod. They differ from instance methods in how they interact with the class and its data.
#
# **1. Class Methods (@classmethod)**
#
# Takes cls (not self) as the first parameter.
#
# Can access class variables and other class methods.
#
# Belongs to the class, not the object.
#
# Commonly used for alternative constructors or class-level operations.
#
# **2. Static Methods (@staticmethod)**
#
# Does not take self or cls as the first argument.
#
# Can't access instance or class variables directly.
#
# Behaves like a regular function, but is logically grouped inside a class.
#
# Used for utility/helper functions related to the class.

# %% [markdown]
# #Question11. What is method overloading in Python?

# %% [markdown]
# #Answer.
# Method Overloading means defining multiple methods with the same name but different parameters (number or type). It's a common feature in many languages like Java or C++, but in Python, method overloading is not supported in the traditional sense.
#
# **How to Simulate Method Overloading in Python**
#
#
# Default arguments
#
# Variable-length arguments (*args, **kwargs)
#
# Manual type checking

# %% [markdown]
# #Question12. What is method overriding in OOP?

# %% [markdown]
# #Answer.
# Method Overriding is a key feature of Object-Oriented Programming (OOP) that allows a child class to provide a specific implementation of a method that is already defined in its parent class.
#
# **Key Points:**
#
# Same method name and parameters as the parent class.
#
# Defined in a child/subclass.
#
# Enables runtime polymorphism.
#
# The child class's method replaces (overrides) the parent class's method when called through an object of the child.

# %% [markdown]
# #Question13.What is a property decorator in Python?

# %% [markdown]
# #Answer.
# The @property decorator in Python is used to convert a method into a read-only property. It allows you to access a method like an attribute, providing a clean and Pythonic way to use getters and setters without explicitly calling methods.
#
# **Why use @property?**
#
# Encapsulates instance variables.
#
# Allows controlled access to private attributes.
#
# Keeps syntax clean and intuitive (obj.attr instead of obj.get_attr()).

# %% [markdown]
# #Question14.Why is polymorphism important in OOP?

# %% [markdown]
# #Answer.
# Polymorphism—meaning "many forms"—is crucial in OOP because it allows objects of different classes to be used interchangeably if they share a common interface (like a method name). It enables flexibility, scalability, and clean, maintainable code.
#
# **Key Reasons Polymorphism is Important:**
#
# **1.** Code Reusability and Flexibility.
#
# **2.** Simplifies Code Maintenance.
#
# **3.** Enables Extensibility.

# %% [markdown]
# #Question15. What is an abstract class in Python?

# %% [markdown]
# #Answer.
# An abstract class in Python is a class that cannot be instantiated directly and is designed to be a blueprint for other classes. It defines abstract methods that must be implemented by its child classes.
#
# **Key Characteristics:**
#
# Defined using the abc module (abc = Abstract Base Class).
#
# Contains one or more abstract methods (methods without implementation).
#
# Can't create an object from an abstract class.
#
# Enforces that subclasses must implement certain methods.

# %% [markdown]
# #Question16. What are the advantages of OOP?

# %% [markdown]
# #Answer.
# Object-Oriented Programming (OOP) is a programming paradigm based on the concept of "objects" — data structures that contain both data (attributes) and behavior (methods). It helps organize code in a modular, reusable, and scalable way.
#
# **Key Advantages of OOP:**
#
# **1**. Modularity
#
# **2**. Reusability through Inheritance.
#
# **3.** Polymorphism
#
# **4.** Encapsulation
#
# **5.** Abstraction
#
# **6.** Improved Maintainability & Scalability
#
# **7.** Real-World Modeling
#
# **8.** Ease of Testing and Debugging

# %% [markdown]
# #Question17. What is the difference between a class variable and an instance variable ?

# %% [markdown]
# #Answer.
# In Python's object-oriented programming, class variables and instance variables are both used to store data, but they differ in scope, lifetime, and behavior.
#
# **1. Class Variable**
#
# Belongs to the class itself, not to any specific object.
#
# Shared across all instances of the class.
#
# Defined outside of any method, typically at the class level.
#
# **2. Instance Variable**
#
# Belongs to a specific object (instance).
#
# Each object has its own copy of the variable.
#
# Defined using self. inside methods (usually in __init__()).

# %% [markdown]
# #Question18. What is multiple inheritance in Python?

# %% [markdown]
# #Answer.
# Multiple Inheritance is a feature in object-oriented programming where a class can inherit from more than one parent class. This allows the child class to access attributes and methods from all its parent classes.
#
# **Syntax of multiple inheritance :**
#
# class Parent1:
#     # Code for Parent1
#
# class Parent2:
#     # Code for Parent2
#
# class Child(Parent1, Parent2):
#     # Inherits from both Parent1 and Parent2
#
#    **Example:**
#
# class Father:
#
#     def skills(self):
#        print("Father: Gardening, Carpentry")
#
# class Mother:
#
#     def skills(self):
#         print("Mother: Cooking, Painting")
#
# class Child(Father, Mother):
#
#     def skills(self):
#         print("Child: ", end="")
#         super().skills()  # Calls the method from the first parent (Father)
#
# c = Child()
#
# c.skills()  # Output: Child: Gardening, Carpentry

# %% [markdown]
# #Question19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?

# %% [markdown]
# #Answer.
# In Python, the __str__ and __repr__ methods are special (dunder) methods that define how objects of a class are represented as strings. They are useful for debugging, logging, and user-friendly output.
#
# **__str__ Method:**
#
# Purpose: Returns a readable, user-friendly string representation of the object.
#
# Usage: Called by the built-in str() function and by print().
#
#  **__repr__ Method:**
#
# Purpose: Returns a detailed, unambiguous string representation of the object, mainly for developers.
#
# Usage: Called by the built-in repr() function and used in the Python shell (or when an object is returned in a list/dict).

# %% [markdown]
# #Question20.What is the significance of the ‘super()’ function in Python ?

# %% [markdown]
# #Answer.
# The super() function in Python is used to call methods from a parent (or superclass) in a subclass. It plays a crucial role in inheritance, especially with multiple inheritance or method overriding.
#
# **Example :**
# class Parent:
#     def greet(self):
#         print("Hello from Parent")
#
# class Child(Parent):
#     def greet(self):
#         super().greet()  # Calls Parent's greet
#         print("Hello from Child")
#
# c = Child()
# c.greet()

# %% [markdown]
# #Question21.What is the significance of the __del__ method in Python ?

# %% [markdown]
# #Answer.
# The __del__ method in Python is a destructor — it is called automatically when an object is about to be destroyed (i.e., when there are no more references to it).
#
# **Purpose of __del__:**
#
# To define cleanup behavior for objects, such as:
#
# Releasing resources (e.g., closing files or network connections).
#
# Logging object deletion.
#
# Freeing up memory (less common in Python due to garbage collection).
#
# **Basic Syntax:**
#
# def __del__(self): # cleanup code

# %% [markdown]
# #Question22.  What is the difference between @staticmethod and @classmethod in Python ?

# %% [markdown]
# #Answer.
# In Python, @staticmethod and @classmethod are decorators used to define methods that aren't quite like regular instance methods. Here's a clear breakdown of their differences:
#
# **@staticmethod -**
#
#  No self or cls
#
# Behaves like a regular function, but lives in the class's namespace.
#
# Doesn't access or modify class or instance state.
#
#
# **@classmethod -**
#
# Uses cls
#
# Receives the class (cls) as the first argument instead of the instance (self).
#
# Can access and modify class variables or even create new instances.

# %% [markdown]
# #Question23. How does polymorphism work in Python with inheritance?

# %% [markdown]
# #Answer.
# Polymorphism means "many forms" — in Python OOP, it allows objects of different classes to be treated as objects of a common superclass, even though they may behave differently.
#
# **Example :**
#
# class Animal:
#
#     def speak(self):
#
#         return "Some sound"
#
# class Dog(Animal):
#
#     def speak(self):
#
#         return "Bark"
#
# class Cat(Animal):
#
#     def speak(self):
#
#         return "Meow"
#
# **Polymorphism in action**
#
# def animal_sound(animal):
#
#     print(animal.speak())
#
# a = Animal()
#
# d = Dog()
#
# c = Cat()
#
# animal_sound(a)  # Output: Some sound
#
# animal_sound(d)  # Output: Bark
#
# animal_sound(c)  # Output: Meow

# %% [markdown]
# #Question24. What is method chaining in Python OOP?

# %% [markdown]
# #Answer.
# Method chaining is a programming technique where multiple methods are called on the same object in a single line of code. Each method returns the object itself (usually self), allowing the next method to be called on it.
#
# **Example of Method Chaining:**
#
# class Person:
#
#     def __init__(self, name=""):
#         self.name = name
#         self.age = 0
#
#     def set_name(self, name):
#         self.name = name
#         return self  # return self to allow chaining
#
#     def set_age(self, age):
#         self.age = age
#         return self
#
#     def display(self):
#         print(f"Name: {self.name}, Age: {self.age}")
#         return self
#
# ** Using method chaining**
#
# p = Person()
#
# p.set_name("Alice").set_age(30).display()
#
# Name: Alice, Age: 30

# %% [markdown]
# #Question25. What is the purpose of the call method in Python?

# %% [markdown]
# #Answer.
# The __call__ method allows an object to be called like a function.
#
# When you define the __call__ method in a class, you can use instances of that class as if they were functions.
#
# **Example :**
#
# class Greeter:
#
#     def __init__(self, name):
#         self.name = name
#
#     def __call__(self, message):
#         return f"{message}, {self.name}!"
#
# g = Greeter("Alice")
#
# print(g("Hello"))  # Output: Hello, Alice!

# %% [markdown]
# #Practical Questions

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".
# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create instances
generic_animal = Animal()
dog = Dog()

# Call speak methods
generic_animal.speak()  # Output: The animal makes a sound.
dog.speak()             # Output: Bark!
# Out:
# The animal makes a sound.
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
c = Circle(5)
r = Rectangle(4, 6)

print(f"Area of Circle: {c.area():.2f}")     # Output: Area of Circle: 78.54
print(f"Area of Rectangle: {r.area()}")      # Output: Area of Rectangle: 24
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_brand(self):
        print(f"Car Brand: {self.brand}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def display_battery(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Create an instance of ElectricCar
tesla = ElectricCar("Electric Vehicle", "Tesla", 85)

# Call methods
tesla.display_type()       # Output: Vehicle Type: Electric Vehicle
tesla.display_brand()      # Output: Car Brand: Tesla
tesla.display_battery()    # Output: Battery Capacity: 85 kWh
# Out:
# Vehicle Type: Electric Vehicle
# Car Brand: Tesla
# Battery Capacity: 85 kWh

# %%
#4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("This bird can fly.")

# Derived class
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they swim well.")

# Polymorphic function
def bird_flight(bird):
    bird.fly()

# Create instances
generic_bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

# Demonstrate polymorphism
bird_flight(generic_bird)  # Output: This bird can fly.
bird_flight(sparrow)       # Output: Sparrow flies high in the sky.
bird_flight(penguin)       # Output: Penguins cannot fly, but they swim well.
# Out:
# This bird can fly.
# Sparrow flies high in the sky.
# Penguins cannot fly, but they swim well.

# %%
#5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ₹{amount}")
        else:
            print("Deposit amount must be positive.")

    # Public method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ₹{amount}")
        else:
            print("Insufficient balance or invalid amount.")

    # Public method to check balance
    def check_balance(self):
        print(f"Current balance: ₹{self.__balance}")

# Example usage
account = BankAccount(1000)
account.check_balance()     # Output: ₹1000
account.deposit(500)        # Output: Deposited ₹500
account.withdraw(300)       # Output: Withdrew ₹300
account.check_balance()     # Output: ₹1200
# Out:
# Current balance: ₹1000
# Deposited ₹500
# Withdrew ₹300
# Current balance: ₹1200

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("Playing an instrument.")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# Runtime polymorphism demonstration
def perform(instrument):
    instrument.play()

# Create objects of each type
guitar = Guitar()
piano = Piano()

# Pass derived class objects to function expecting base class type
perform(guitar)  # Output: Strumming the guitar.
perform(piano)   # Output: Playing the piano.
# Out:
# Strumming the guitar.
# Playing the piano.

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Using the class method
sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)  # Output: Sum: 15

# Using the static method
difference_result = MathOperations.subtract_numbers(10, 5)
print("Difference:", difference_result)  # Output: Difference: 5
# Out:
# Sum: 15
# Difference: 5

# %%
#8. Implement a class Person with a class method to count the total number of persons created
class Person:
    count = 0  # Class variable to keep track of number of persons

    def __init__(self, name):
        self.name = name
        Person.count += 1  # Increment count whenever a new object is created

    @classmethod
    def total_persons(cls):
        return cls.count

# Creating Person instances
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

# Get total number of persons created
print("Total persons created:", Person.total_persons())  # Output: 3
# Out:
# Total persons created: 3

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating Fraction objects
f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

# Printing fractions
print(f1)  # Output: 3/4
print(f2)  # Output: 5/8
# Out:
# 3/4
# 5/8

# %%
#10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors.
class vector():
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def __add__(self,other):
    return vector(self.x + other.x, self.y+other.y)

  def __str__(self):
    return f"({self.x},{self.y})"

v1 = vector(3,4)
v2 = vector(5,6)
v3 = v1+v2

print("v1:", v1)  # Output: (2, 3)
print("v2:", v2)  # Output: (4, 5)
print("v1 + v2 =", v3)  # Output: (6, 8)
# Out:
# v1: (3,4)
# v2: (5,6)
# v1 + v2 = (8,10)

# %%
#11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."
class person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello,my name is{self.name} and I am {self.age} years old")

p1 = person("Alice",25)
p1.greet()
# Out:
# Hello,my name isAlice and I am 25 years old

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades.
class student:
  def __init__(self,name,grades):
    self.name = name
    self.grades =  grades

  def average_grade(self):
    if not self.grades:
      return 0 # avoid division by zero
    return sum(self.grades)/len(self.grades)
# creating a student object
s1 = student("John",[85,90,78,92])

print(f"Average grade for {s1.name} is {s1.average_grade()}")
# Out:
# Average grade for John is 86.25

# %%
#13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#area.
class Rectangle:
  def __init__(self):
    self.length = 0
    self.width = 0
  def set_dimesions(self,length,width):
    self.length = length
    self.width = width
  def area(self):
    return self.length * self.width

rect = Rectangle()
rect.set_dimesions(5,3)
print("Area of rectangle:",rect.area())
# Out:
# Area of rectangle: 15

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary.
#Base Class
class Employee:
  def __init__(self,name,hourly_worked,hourly_rate):
    self.name = name
    self.hourly_worked = hourly_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hourly_worked*self.hourly_rate

#Derived Class
class Manager(Employee):
  def __init__(self,name,hourly_worked,hourly_rate,bonus):
    super().__init__(name,hourly_worked,hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    base_salary = super().calculate_salary()
    return base_salary + self.bonus

emp = Employee("Alice", 40, 20)
mgr = Manager("Bob", 40, 30, 500)

# Calculating salaries
print(f"{emp.name}'s Salary: ${emp.calculate_salary()}")  # Output: 800
print(f"{mgr.name}'s Salary: ${mgr.calculate_salary()}")  # Output: 1700
# Out:
# Alice's Salary: $800
# Bob's Salary: $1700

# %%
#15.Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Creating a Product object
p1 = Product("Laptop", 60000, 2)

# Calculating and printing the total price
print(f"Product: {p1.name}")
print(f"Total price: ₹{p1.total_price()}")  # Output: ₹120000
# Out:
# Product: Laptop
# Total price: ₹120000

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# Create objects and demonstrate polymorphism
cow = Cow()
sheep = Sheep()

print("Cow says:", cow.sound())     # Output: Moo
print("Sheep says:", sheep.sound()) # Output: Baa
# Out:
# Cow says: Moo
# Sheep says: Baa

# %%
#17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Creating a Book object
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

# Printing book information
print(book1.get_book_info())
# Output: 'To Kill a Mockingbird' by Harper Lee, published in 1960
# Out:
# 'To Kill a Mockingbird' by Harper Lee, published in 1960

# %%
#18.Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)  # Call base class constructor
        self.number_of_rooms = number_of_rooms

# Creating a Mansion object
mansion = Mansion("123 Luxury Lane", 50000000, 12)

# Displaying mansion details
print("Address:", mansion.address)
print("Price: ₹", mansion.price)
print("Number of Rooms:", mansion.number_of_rooms)
# Out:
# Address: 123 Luxury Lane
# Price: ₹ 50000000
# Number of Rooms: 12
